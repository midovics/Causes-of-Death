# %% [markdown]
# # Causes of Death Analysis

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# ## 1. Import Libraries and Data

# %% [markdown]
# ## 1.1 Variables and Data Types (Causes_of_deaths dataset)

# %% [markdown]
# ## 2. Data Cleaning and Consistency Check¶
# 2.1 Find Missing Values
#
# 2.2 Find Duplicates
#
# 2.3 Find Mixed-Type Values

# %% [markdown]
# ## 3.Export Causes_of_deaths dataframe

# %% [markdown]
# ## 01. Import Libraries and Data

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %%
#Create a path
path=r'C:\Users\midov\Documents\Studies\Data Analysis\Immersion into Data Analytics\Achievement 6_Advanced Analytics & Dashboard Design\Causes of Death Analysis'

# %%
#Import "Causes_of_deaths.csv" file as df_causes, using path variable
df_causes=pd.read_csv(os.path.join(path,'Data','Original Data','Causes_of_deaths.csv'))

# %%
#Check the df
df_causes.info()
df_causes.describe().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2244 entries, 0 to 2243
# Data columns (total 34 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country/Territory                           2244 non-null   object
#  1   Code                                        2244 non-null   object
#  2   Year                                        2244 non-null   int64
#  3   Meningitis                                  2244 non-null   int64
#  4   Alzheimer's Disease and Other Dementias     2244 non-null   int64
#  5   Parkinson's Disease                         2244 non-null   int64
#  6   Nutritional Deficiencies                    2244 non-null   int64
#  7   Malaria                                     2244 non-null   int64
#  8   Drowning                                    2244 non-null   int64
#  9   Interpersonal Violence                      2244 non-null   int64
# ...

# %%
#Check the first 5 rows
df_causes.head()
# Out:
#   Country/Territory Code  Year  Meningitis  \
# 0       Afghanistan  AFG  2009        2460
# 1       Afghanistan  AFG  2010        2410
# 2       Afghanistan  AFG  2011        2327
# 3       Afghanistan  AFG  2012        2254
# 4       Afghanistan  AFG  2013        2281
#
#    Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                     1449                  460
# 1                                     1476                  465
# 2                                     1508                  473
# 3                                     1544                  482
# 4                                     1581                  491
#
#    Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  ...  \
# 0                      2040      239      1852                    3874  ...
# 1                      1974      377      1837                    4130  ...
# 2                      1846      390      1775                    4170  ...
# ...

# %%
#Check the number of rows and columns
df_causes.shape
# Out:
# (2244, 34)

# %% [markdown]
# ## 1.1 Variables and Data Types (Causes_of_deaths dataset)
# ![image-3.png](attachment:image-3.png)

# %%
#Check the total number of countries
df_causes['Country/Territory'].nunique()
# Out:
# 204

# %%
#Check the total number of year data provided for each country
df_causes['Country/Territory'].value_counts()
# Out:
# Afghanistan         11
# Papua New Guinea    11
# Niue                11
# North Korea         11
# North Macedonia     11
#                     ..
# Greenland           11
# Grenada             11
# Guam                11
# Guatemala           11
# Zimbabwe            11
# Name: Country/Territory, Length: 204, dtype: int64

# %% [markdown]
# ## 02. Data Cleaning and Consistency Check

# %%
#Rename the columns 
df_causes2 = df_causes.rename(columns=lambda x: x.replace("'",'_'))

# %%
print(df_causes2)
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 0          Afghanistan  AFG  2009        2460
# 1          Afghanistan  AFG  2010        2410
# 2          Afghanistan  AFG  2011        2327
# 3          Afghanistan  AFG  2012        2254
# 4          Afghanistan  AFG  2013        2281
# ...                ...  ...   ...         ...
# 2239          Zimbabwe  ZWE  2015        1439
# 2240          Zimbabwe  ZWE  2016        1457
# 2241          Zimbabwe  ZWE  2017        1460
# 2242          Zimbabwe  ZWE  2018        1450
# 2243          Zimbabwe  ZWE  2019        1450
#
#       Alzheimer_s Disease and Other Dementias  Parkinson_s Disease  \
# 0                                        1449                  460
# 1                                        1476                  465
# 2                                        1508                  473
# 3                                        1544                  482
# 4                                        1581                  491
# ...

# %%
#Rename the columns
df_causes2.rename(columns = {'Country/Territory' : 'Country', 'Country Code' : 'Code',
       'Alzheimer_s Disease and Other Dementias' : 'Alzheimer_s_Disease_and_Other_Dementias' , 'Parkinson_s Disease' :'Parkinson_s_Disease','Nutritional Deficiencies' : 'Nutritional_Deficiencies','Interpersonal Violence' : 'Interpersonal_Violence', 'Maternal Disorders' : 'Maternal_Disorders', 'HIV/AIDS' :'HIV_AIDS','Drug Use Disorders' : 'Drug_Use_Disorders', 'Cardiovascular Diseases' : 'Cardiovascular_Diseases','Lower Respiratory Infections' : 'Lower_Respiratory_Infections', 'Neonatal Disorders' : 'Neonatal_Disorders','Alcohol Use Disorders' : 'Alcohol_Use_Disorders', 'Self-harm' : 'Self_harm', 'Exposure to Forces of Nature' : 'Exposure_to_Forces_of_Nature','Diarrheal Diseases' : 'Diarrheal_Diseases', 'Environmental Heat and Cold Exposure' : 'Environmental_Heat_and_Cold_Exposure','Conflict and Terrorism' : 'Conflict_and_Terrorism', 'Diabetes Mellitus' : 'Diabetes_Mellitus','Chronic Kidney Disease' : 'Chronic_Kidney_Disease', 'Protein-Energy Malnutrition' : 'Protein_Energy_Malnutrition','Road Injuries':'Road_Injuries','Chronic Respiratory Diseases':'Chronic_Respiratory_Diseases',
       'Cirrhosis and Other Chronic Liver Diseases': 'Cirrhosis_and_Other_Chronic_Liver_Diseases', 'Digestive Diseases' : 'Digestive_Diseases','Fire, Heat, and Hot Substances' : 'Fire_Heat_and_Hot_Substances', 'Acute Hepatitis' : 'Acute_Hepatitis'}, inplace = True)

# %%
df_causes2.head()
# Out:
#        Country Code  Year  Meningitis  \
# 0  Afghanistan  AFG  2009        2460
# 1  Afghanistan  AFG  2010        2410
# 2  Afghanistan  AFG  2011        2327
# 3  Afghanistan  AFG  2012        2254
# 4  Afghanistan  AFG  2013        2281
#
#    Alzheimer_s_Disease_and_Other_Dementias  Parkinson_s_Disease  \
# 0                                     1449                  460
# 1                                     1476                  465
# 2                                     1508                  473
# 3                                     1544                  482
# 4                                     1581                  491
#
#    Nutritional_Deficiencies  Malaria  Drowning  Interpersonal_Violence  ...  \
# 0                      2040      239      1852                    3874  ...
# 1                      1974      377      1837                    4130  ...
# 2                      1846      390      1775                    4170  ...
# ...

# %% [markdown]
# ## 2.1 Find Missing Values

# %%
#Check for null values
df_causes2.isna().sum()
# Out:
# Country                                       0
# Code                                          0
# Year                                          0
# Meningitis                                    0
# Alzheimer_s_Disease_and_Other_Dementias       0
# Parkinson_s_Disease                           0
# Nutritional_Deficiencies                      0
# Malaria                                       0
# Drowning                                      0
# Interpersonal_Violence                        0
# Maternal_Disorders                            0
# HIV_AIDS                                      0
# Drug_Use_Disorders                            0
# Tuberculosis                                  0
# Cardiovascular_Diseases                       0
# Lower_Respiratory_Infections                  0
# Neonatal_Disorders                            0
# Alcohol_Use_Disorders                         0
# Self_harm                                     0
# Exposure_to_Forces_of_Nature                  0
# ...

# %% [markdown]
# No null entries in the dataset

# %% [markdown]
# ## 2.2 Find Duplicates

# %%
#Check for duplicates
df_dups = df_causes2[df_causes2.duplicated()]

# %%
#Address the duplicates
df_causes_no_dups = df_causes2.drop_duplicates()

# %%
df_causes_no_dups.shape
# Out:
# (2244, 34)

# %% [markdown]
# No duplicates

# %% [markdown]
# ## 2.3 Find Mixed-Type Values

# %%
#Check for mixed data type
for col in df_causes2.columns.tolist():
  weird = (df_causes2[[col]].applymap(type) != df_causes2[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_causes2[weird]) > 0:
    print (col)

# %%
df_causes2.shape
# Out:
# (2244, 34)

# %% [markdown]
# ## 03.Export Causes_of_deaths dataframe

# %%
df_causes2.to_csv(os.path.join(path,'Data','Prepared Data','causes_cleaned.csv'))
